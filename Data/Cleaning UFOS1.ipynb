# %% [markdown]
# # PROJECT #3.
# CLEANING SCRUBBED.CVS DATA

# %%
# Import Dependencies
import pandas as pd
import datetime as dt
from datetime import datetime
from datetime import date
import numpy as np

# %%
# Name of the CSV file
file = 'scrubbed.csv'
#Read the file
df = pd.read_csv(file, encoding="UTF-8")
# Preview of the DataFrame
df.head()
# Out:
# C:\Users\Celvir\AppData\Local\Temp\ipykernel_10648\2275471134.py:4: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, encoding="UTF-8")
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#    longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
# Remove blancks in columns
df.columns = df.columns.str.replace(' ', '')
df.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration(seconds)',
#        'duration(hours/min)', 'comments', 'dateposted', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
#Rename columns
df.rename(columns={'duration(seconds)':'duration_seconds',
            'datetime':'date_ocurrence',
           'duration(hours/min)':'duration_hours_min',
           'dateposted':'date_posted'}
           , inplace=True)
df.head()
# Out:
#      date_ocurrence                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration_seconds duration_hours_min  \
# 0             2700         45 minutes
# 1             7200            1-2 hrs
# 2               20         20 seconds
# 3               20           1/2 hour
# 4              900         15 minutes
#
#                                             comments date_posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#     longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
df.dtypes
# Out:
# date_ocurrence         object
# city                   object
# state                  object
# country                object
# shape                  object
# duration_seconds       object
# duration_hours_min     object
# comments               object
# date_posted            object
# latitude               object
# longitude             float64
# dtype: object

# %%
#Convert list found to lower cases
states=['AL','AK','AZ','AR','AS','CA','CO','CT','DE','DC','FL','GA','GU','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD',
        'MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','MP','OH','OK','OR','PA','PR','RI','SC','SD',
        'TN','TX','TT','UT','VT','VA','VI','WA','WV','WI','WY']

count=0

for state in states:
    word = state.lower()
    states[count]=word
    count += 1

# %%
#Create new dataframe usa
usa_df=df.loc[df["state"].isin(states)]
print(type(usa_df)) 
usa_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          date_ocurrence          city state country     shape  \
# 0      10/10/1949 20:30    san marcos    tx      us  cylinder
# 1      10/10/1949 21:00  lackland afb    tx     NaN     light
# 3      10/10/1956 21:00          edna    tx      us    circle
# 4      10/10/1960 20:00       kaneohe    hi      us     light
# 5      10/10/1961 19:00       bristol    tn      us    sphere
# ...                 ...           ...   ...     ...       ...
# 80327    9/9/2013 21:15     nashville    tn      us     light
# 80328    9/9/2013 22:00         boise    id      us    circle
# 80329    9/9/2013 22:00          napa    ca      us     other
# 80330    9/9/2013 22:20        vienna    va      us    circle
# 80331    9/9/2013 23:00        edmond    ok      us     cigar
#
#       duration_seconds duration_hours_min  \
# 0                 2700         45 minutes
# 1                 7200            1-2 hrs
# 3                   20           1/2 hour
# 4                  900         15 minutes
# 5                  300          5 minutes
# ...                ...                ...
# 80327            600.0         10 minutes
# 80328           1200.0         20 minutes
# 80329           1200.0               hour
# 80330              5.0          5 seconds
# 80331           1020.0         17 minutes
#
#                                                 comments date_posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# 5      My father is now 89 my brother 52 the girl wit...   4/27/2007
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude   longitude
# 0      29.8830556  -97.941111
# 1        29.38421  -98.581082
# 3      28.9783333  -96.645833
# 4      21.4180556 -157.803611
# 5          36.595  -82.188889
# ...           ...         ...
# 80327   36.165833  -86.784444
# 80328   43.613611 -116.202500
# 80329   38.297222 -122.284444
# 80330   38.901111  -77.265556
# 80331   35.652778  -97.477778
#
# [70938 rows x 11 columns]

# %%
#Fill the missing data in country with 'us" for the sightnings in the states
usa_df=usa_df.assign(country="us")
usa_df.count()
# Out:
# date_ocurrence        70938
# city                  70938
# state                 70938
# country               70938
# shape                 69206
# duration_seconds      70938
# duration_hours_min    70938
# comments              70925
# date_posted           70938
# latitude              70938
# longitude             70938
# dtype: int64

# %%
#Clean the typo in latitude
df[df["latitude"] == "33q.200088"]
# Out:
#        date_ocurrence                          city state country      shape  \
# 43782  5/22/1974 5:30  mescalero indian reservation    nm     NaN  rectangle
#
#       duration_seconds duration_hours_min  \
# 43782              180          two hours
#
#                                                 comments date_posted  \
# 43782  Huge rectangular object emmitting intense whit...   4/18/2012
#
#          latitude   longitude
# 43782  33q.200088 -105.624152

# %%
df.at[43782,'latitude']=33.200088
df.at[43782,'latitude']
# Out:
# 33.200088

# %%
#Clean seconds so we convert them to float
df['duration_seconds'] = df['duration_seconds'].str.replace('`','')

# %%
#Convert duration_seconds to float
df['duration_seconds']= df['duration_seconds'].astype(float)

# %%
#Convert latitude to float
df['latitude']= df['latitude'].astype(float)

# %%
#Check types in dataframe
df.dtypes
# Out:
# date_ocurrence         object
# city                   object
# state                  object
# country                object
# shape                  object
# duration_seconds      float64
# duration_hours_min     object
# comments               object
# date_posted            object
# latitude              float64
# longitude             float64
# dtype: object

# %%
#Check for missing data

df.count()
# Out:
# date_ocurrence        80332
# city                  80332
# state                 74535
# country               70662
# shape                 78400
# duration_seconds      65536
# duration_hours_min    80332
# comments              80317
# date_posted           80332
# latitude              80332
# longitude             80332
# dtype: int64

# %%
#Check cities to avoid typos
df['city'].value_counts()
# Out:
# seattle                                  525
# phoenix                                  454
# portland                                 374
# las vegas                                368
# los angeles                              353
#                                         ...
# playa del cura (grand canaria island)      1
# livermore/pleasonton (area)                1
# hamburg (germany)                          1
# cole camp                                  1
# hamstead (hollyridge)                      1
# Name: city, Length: 19900, dtype: int64

# %%
#example of a cell corrected:
df[df['city'] == "hamstead (hollyridge)"]
# Out:
#        date_ocurrence                   city state country  shape  \
# 80324  9/9/2013 21:00  hamstead (hollyridge)    nc     NaN  light
#
#        duration_seconds duration_hours_min  \
# 80324               NaN          2 minutes
#
#                                                 comments date_posted  \
# 80324  8 to ten lights bright orange in color large t...   9/30/2013
#
#         latitude  longitude
# 80324  34.367594 -77.710548

# %%
df.at[80324,'city']="hampstead"
df[df['city'] == "hampstead"]
# Out:
#          date_ocurrence       city state country     shape  duration_seconds  \
# 1734   10/15/1967 21:00  hampstead    nc      us      disk             300.0
# 13610   11/29/1998 1:50  hampstead    nc      us  fireball              18.0
# 13892  11/30/2013 18:00  hampstead    nh      us    sphere             900.0
# 14113    1/13/2008 5:20  hampstead    nh      us     light             120.0
# 14173    1/13/2011 7:30  hampstead    nh      us    circle             180.0
# 21011  12/28/2005 15:30  hampstead    nh      us    sphere            1200.0
# 42919   5/17/2009 22:00  hampstead    nc      us  triangle             300.0
# 44222   5/25/1991 21:00  hampstead    nh      us      disk             120.0
# 53410     6/3/2013 9:34  hampstead    nh      us  triangle               3.0
# 58460    7/20/2012 9:55  hampstead    nh      us    circle             300.0
# 80275     9/9/2011 9:30  hampstead    nc      us   diamond               NaN
# 80324    9/9/2013 21:00  hampstead    nc     NaN     light               NaN
#
#       duration_hours_min                                           comments  \
# 1734           5 minutes                 Hampstead North Carolina disk 1967
# 13610          18seconds  As we steped out of our car we saw a fireball ...
# 13892         15 minutes  3 red spheres&#44 low hovering over lake. Move...
# 14113          2 minutes  Bright Light In Sky Over Rockingham County&#44 NH
# 14173          3 minutes  Round shiny extremely bright almost silver-loo...
# 21011            20 mins  2 ballon shaped objects came close and then se...
# 42919          5 minutes  Star Destroyer shaped ufo low in the night sky...
# 44222              2 min  It sailed through the sky directly above our b...
# 53410          3 seconds         Green cloudy light shooting across the sky
# 58460          5 minutes  Bright lighted object zigzagging through the sky.
# 80275           4-5 min.  Hampstead&#44 N.C 9:30 P.M.  diamond   5 minut...
# 80324          2 minutes  8 to ten lights bright orange in color large t...
#
#       date_posted   latitude  longitude
# 1734   12/20/2012  34.367500 -77.710833
# 13610   1/28/1999  34.367500 -77.710833
# 13892   12/2/2013  42.874444 -71.181667
# 14113   1/21/2008  42.874444 -71.181667
# 14173   1/31/2011  42.874444 -71.181667
# 21011   3/11/2006  42.874444 -71.181667
# 42919  12/12/2009  34.367500 -77.710833
# 44222  12/19/2003  42.874444 -71.181667
# 53410    7/3/2013  42.874444 -71.181667
# 58460    8/5/2012  42.874444 -71.181667
# 80275  10/10/2011  34.367500 -77.710833
# 80324   9/30/2013  34.367594 -77.710548

# %%
#Check code of states to avoid errors
df['state'].unique()
# Out:
# array(['tx', nan, 'hi', 'tn', 'ct', 'al', 'fl', 'ca', 'nc', 'ny', 'ky',
#        'mi', 'ma', 'ks', 'sc', 'wa', 'ab', 'co', 'nh', 'wi', 'me', 'ga',
#        'pa', 'il', 'ar', 'on', 'mo', 'oh', 'in', 'az', 'mn', 'nv', 'nf',
#        'ne', 'or', 'bc', 'ia', 'va', 'id', 'nm', 'nj', 'mb', 'wv', 'ok',
#        'ri', 'nb', 'vt', 'la', 'pr', 'ak', 'ms', 'ut', 'md', 'mt', 'sk',
#        'wy', 'sd', 'pq', 'ns', 'qc', 'de', 'nd', 'dc', 'nt', 'sa', 'yt',
#        'yk', 'pe'], dtype=object)

# %%
#check ocurrences per state
df['state'].value_counts()
# Out:
# ca    9655
# wa    4268
# fl    4200
# tx    3677
# ny    3219
#       ...
# nf      25
# nt      20
# pe      17
# yt      13
# yk       7
# Name: state, Length: 67, dtype: int64

# %%
#Count sightnings reported by country
df['country'].value_counts()
# Out:
# us    65114
# ca     3000
# gb     1905
# au      538
# de      105
# Name: country, dtype: int64

# %%
df['date_posted'].value_counts()
# Out:
# 12/12/2009    1510
# 10/30/2006    1408
# 11/21/2010    1237
# 10/31/2008    1164
# 3/19/2009     1098
#               ...
# 3/1/2004         4
# 1/20/2003        2
# 5/23/1999        2
# 1/10/2003        1
# 3/25/2002        1
# Name: date_posted, Length: 317, dtype: int64

# %%
df['date_ocurrence'].value_counts()
# Out:
# 7/4/2010 22:00      36
# 7/4/2012 22:00      31
# 11/16/1999 19:00    27
# 9/19/2009 20:00     26
# 7/4/2011 22:00      25
#                     ..
# 2/21/2008 1:38       1
# 2/21/2008 2:00       1
# 2/21/2008 7:00       1
# 2/21/2008 9:45       1
# 9/9/2013 23:00       1
# Name: date_ocurrence, Length: 69474, dtype: int64

# %%
# List unique values of "shape" fyi
df["shape"].unique()
# Out:
# array(['cylinder', 'light', 'circle', 'sphere', 'disk', 'fireball',
#        'unknown', 'oval', 'other', 'cigar', 'rectangle', 'chevron',
#        'triangle', 'formation', nan, 'delta', 'changing', 'egg',
#        'diamond', 'flash', 'teardrop', 'cone', 'cross', 'pyramid',
#        'round', 'crescent', 'flare', 'hexagon', 'dome', 'changed'],
#       dtype=object)

# %%
df['shape'].value_counts()
# Out:
# light        16565
# triangle      7865
# circle        7608
# fireball      6208
# other         5649
# unknown       5584
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# round            2
# crescent         2
# pyramid          1
# flare            1
# hexagon          1
# dome             1
# changed          1
# Name: shape, dtype: int64

# %%
df.loc[df["shape"]=="round","shape"]="sphere"

# %%
df.loc[df["shape"]=="unknown","shape"]="other"

# %%
df[df["shape"]=="other"]
# Out:
#          date_ocurrence             city state country  shape  \
# 13     10/10/1970 19:00       manchester    ky      us  other
# 19     10/10/1974 19:30           hudson    ma      us  other
# 25     10/10/1977 12:00      san antonio    tx      us  other
# 31     10/10/1979 22:00         security    co      us  other
# 33     10/10/1980 22:00           dallas    tx      us  other
# ...                 ...              ...   ...     ...    ...
# 80313     9/9/2013 0:15          norfolk    va      us  other
# 80315     9/9/2013 3:00        struthers    oh      us  other
# 80318    9/9/2013 13:10  calmar (canada)    ab      ca  other
# 80319    9/9/2013 20:15          clifton    nj     NaN  other
# 80329    9/9/2013 22:00             napa    ca      us  other
#
#        duration_seconds duration_hours_min  \
# 13                180.0          3 minutes
# 19               2700.0         45 minutes
# 25                 30.0         30 seconds
# 31               1800.0            30mins.
# 33                300.0          5 minutes
# ...                 ...                ...
# 80313               NaN       split second
# 80315               NaN          2 minutes
# 80318               NaN      45-90 seconds
# 80319               NaN              ~1hr+
# 80329               NaN               hour
#
#                                                 comments date_posted  \
# 13     Slow moving&#44 silent craft accelerated at an...   2/14/2008
# 19     Not sure of the eact month or year of this sig...   8/10/1999
# 25     i was about six or seven and my family and me ...   2/24/2005
# 31     very low clouds all different colors&#44search...   1/28/1999
# 33     Strange shape shifting craft of pure light ene...  10/28/2002
# ...                                                  ...         ...
# 80313  Two or three lights shoot across sky over nava...   9/30/2013
# 80315  I saw a routaing line of stares that seemed to...    9/9/2013
# 80318        Fastest dot I have ever seen in the sky&#33    9/9/2013
# 80319              Luminous line seen in New Jersey sky.   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
#
#         latitude   longitude
# 13     37.153611  -83.761944
# 19     42.391667  -71.566667
# 25     29.423889  -98.493333
# 31     38.758333 -104.742500
# 33     32.783333  -96.800000
# ...          ...         ...
# 80313  36.846667  -76.285556
# 80315  41.052500  -80.608056
# 80318  53.250000 -113.783333
# 80319  40.858433  -74.163755
# 80329  38.297222 -122.284444
#
# [11233 rows x 11 columns]

# %%
df.loc[df["shape"].isna(),"shape"]="not specified"

# %%
df[df["shape"]=="not specified"]
# Out:
#          date_ocurrence                                       city state  \
# 62     10/10/1995 19:45                                  milwaukee    wi
# 63     10/10/1995 22:40                                    oakland    ca
# 239    10/10/2011 19:30                         murfeesboro/smyrna    tn
# 285    10/11/1986 20:30          alice springs  (nt&#44 australia)   NaN
# 293    10/11/1995 18:30                   new york city (brooklyn)    ny
# ...                 ...                                        ...   ...
# 80128    9/9/1999 22:00                               mount shasta    ca
# 80155    9/9/2002 19:02  moriches bay (long island/atlantic ocean)    ny
# 80156    9/9/2002 19:02                 moriches bay (long island)    ny
# 80179    9/9/2003 22:00                                   prescott    az
# 80237    9/9/2009 13:00                                   mesquite    nv
#
#       country          shape  duration_seconds     duration_hours_min  \
# 62         us  not specified             120.0                 2 min.
# 63         us  not specified              60.0               1 minute
# 239       NaN  not specified            2700.0          30-45 minutes
# 285        au  not specified              20.0             20 seconds
# 293        us  not specified             720.0                12 min.
# ...       ...            ...               ...                    ...
# 80128      us  not specified               NaN                5 hours
# 80155     NaN  not specified               NaN                30 sec.
# 80156     NaN  not specified               NaN  1 minute&#44 or less.
# 80179      us  not specified               NaN             45 minutes
# 80237      us  not specified               NaN          10 to 15 mins
#
#                                                 comments date_posted  \
# 62     Man  on Hwy 43 SW of Milwaukee sees large&#44 ...   11/2/1999
# 63     Woman repts.  bright light in NW sky&#44 sudde...   11/2/1999
# 239    Multi color oblect over Smyrna/Murfreesboro 10...  10/19/2011
# 285    Being  of light reported&#44Jesus or another m...   1/19/2005
# 293    Young man&#44 mother witness watch strange red...   11/2/1999
# ...                                                  ...         ...
# 80128  multiple anomalious lights&#44white flashes&#4...   10/2/1999
# 80155  Two men report witnessing a peculiar object de...   9/13/2002
# 80156  U. S. Coast Guard (Boston) forwards report of ...   9/13/2002
# 80179  Bright &quot;stars&quot; flying in sky in Pres...    8/7/2007
# 80237                       ((HOAX??))  dino over nevada  12/12/2009
#
#         latitude   longitude
# 62     43.038889  -87.906389
# 63     37.804444 -122.269722
# 239    35.947474  -86.488367
# 285   -23.697479  133.883621
# 293    40.714167  -74.006389
# ...          ...         ...
# 80128  41.310000 -122.309444
# 80155  40.789394  -72.715627
# 80156  40.789394  -72.715627
# 80179  34.540000 -112.467778
# 80237  36.805556 -114.066389
#
# [1932 rows x 11 columns]

# %%
#Clean the typos in shapes
df[df["shape"]=="changed"].assign(shape="changing")
#df[df["shape"]=="round"].assign(shape="sphere")
# Out:
#        date_ocurrence    city state country     shape  duration_seconds  \
# 51412  6/24/1996 0:30  aurora    co      us  changing            3600.0
#
#       duration_hours_min                                           comments  \
# 51412             1 hour  Obj. hovered 100 ft above car.  Red&#44 blue l...
#
#       date_posted   latitude   longitude
# 51412   11/2/1999  39.729444 -104.831389

# %%
df[df["shape"].isnull()]    #.assign(shape="changing")
# Out:
# Empty DataFrame
# Columns: [date_ocurrence, city, state, country, shape, duration_seconds, duration_hours_min, comments, date_posted, latitude, longitude]
# Index: []

# %%
#Create the dataframe for the comments
df_comments=pd.DataFrame(index=df.index)

# %%
df_comments['date_ocurrence']=df['date_ocurrence']

# %%
df_comments[['latitude','longitude','comments']]=df[['latitude','longitude','comments']]

# %%
df_comments.dtypes
# Out:
# date_ocurrence     object
# latitude          float64
# longitude         float64
# comments           object
# dtype: object

# %%
df.dtypes
# Out:
# date_ocurrence         object
# city                   object
# state                  object
# country                object
# shape                  object
# duration_seconds      float64
# duration_hours_min     object
# comments               object
# date_posted            object
# latitude              float64
# longitude             float64
# dtype: object

# %%
#Drop comments from the firts database
df.drop(columns=['comments'], inplace=True)
df
# Out:
#          date_ocurrence                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#        duration_seconds duration_hours_min date_posted   latitude   longitude
# 0                2700.0         45 minutes   4/27/2004  29.883056  -97.941111
# 1                7200.0            1-2 hrs  12/16/2005  29.384210  -98.581082
# 2                  20.0         20 seconds   1/21/2008  53.200000   -2.916667
# 3                  20.0           1/2 hour   1/17/2004  28.978333  -96.645833
# 4                 900.0         15 minutes   1/22/2004  21.418056 -157.803611
# ...                 ...                ...         ...        ...         ...
# 80327               NaN         10 minutes   9/30/2013  36.165833  -86.784444
# 80328               NaN         20 minutes   9/30/2013  43.613611 -116.202500
# 80329               NaN               hour   9/30/2013  38.297222 -122.284444
# 80330               NaN          5 seconds   9/30/2013  38.901111  -77.265556
# 80331               NaN         17 minutes   9/30/2013  35.652778  -97.477778
#
# [80332 rows x 10 columns]

# %%
df.to_csv("UFO_cleaned.csv", index=True, encoding="UTF-8")

# %%
#Drop sightnings without comments
new_df=df_comments.dropna()
new_df
# Out:
#          date_ocurrence   latitude   longitude  \
# 0      10/10/1949 20:30  29.883056  -97.941111
# 1      10/10/1949 21:00  29.384210  -98.581082
# 2      10/10/1955 17:00  53.200000   -2.916667
# 3      10/10/1956 21:00  28.978333  -96.645833
# 4      10/10/1960 20:00  21.418056 -157.803611
# ...                 ...        ...         ...
# 80327    9/9/2013 21:15  36.165833  -86.784444
# 80328    9/9/2013 22:00  43.613611 -116.202500
# 80329    9/9/2013 22:00  38.297222 -122.284444
# 80330    9/9/2013 22:20  38.901111  -77.265556
# 80331    9/9/2013 23:00  35.652778  -97.477778
#
#                                                 comments
# 0      This event took place in early fall around 194...
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...
# 2      Green/Orange circular disc over Chester&#44 En...
# 3      My older brother and twin sister were leaving ...
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...
# ...                                                  ...
# 80327  Round from the distance/slowly changing colors...
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...
# 80329                                       Napa UFO&#44
# 80330  Saw a five gold lit cicular craft moving fastl...
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...
#
# [80317 rows x 4 columns]

# %%
new_df.to_csv("UFO_comments.csv", index=True, encoding="UTF-8")
